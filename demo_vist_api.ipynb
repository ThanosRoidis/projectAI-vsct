# %%
import vist
import matplotlib.pyplot as plt
from datetime import datetime
from pprint import pprint
# %matplotlib inline
plt.rcParams['figure.figsize'] = (10, 10)

# %%
vist_images_dir = 'D:\gnsid\Documents\MSc\projectAI\images'
vist_annotations_dir = 'D:\gnsid\Documents\MSc\projectAI'
sis = vist.Story_in_Sequence(vist_images_dir, vist_annotations_dir, ['val'])
# Out:
# sis's [val] loaded. It took 2.47 seconds.
# Make mapping ...
# Mapping for [Albums][Images][Stories][Sents] done.

# %%
sis.Stories['44128']
# Out:
# {'album_id': '72157603372039550',
#  'id': '44128',
#  'img_ids': ['2086199701',
#   '2086984552',
#   '2086199839',
#   '2086178527',
#   '2086181665'],
#  'sent_ids': ['220640', '220641', '220642', '220643', '220644']}

# %%
sis.Stories['44128']['img_ids']
# Out:
# ['2086199701', '2086984552', '2086199839', '2086178527', '2086181665']

# %%
sis.Sents['220640']
# Out:
# {'album_id': '72157603372039550',
#  'id': '220640',
#  'img_id': '2086199701',
#  'length': 10,
#  'order': 0,
#  'original_text': 'A school bus drove by my broken car today.',
#  'setting': 'last-3-pick-old-and-tell',
#  'story_id': '44128',
#  'text': 'a school bus drove by my broken car today .',
#  'tier': 'story-in-sequence',
#  'worker_id': '2CD6K5S2XPEG1CK'}

# %%
sis.Albums.keys()

# %%
album_id = '72157604508466643'
sis.show_album(album_id)
album = sis.Albums[album_id]
print (album)
# Out:
# {'id': '72157604508466643', 'owner': '62929416@N00', 'title': "Steven's 04/12/08", 'server': '2180', 'secret': 'b41ba9e458', 'date_create': '1208046716', 'date_update': '1430079909', 'description': 'Sunny spring skiing at its finest...T-shirt weather the whole way.\n\nHighlights of the day include hoola-hoop skiing, meade, bbq, and pinkies...', 'story_ids': ['41694', '41691', '41692', '41690', '41693'], 'farm': '3', 'primary': '2408214539', 'vist_label': 'bar_mitzvah', 'split': 'val', 'photos': '29', 'img_ids': ['2409037596', '2409095176', '2408189765', '2408189997', '2409022122', '2408190605', '2409022866', '2409023744', '2408192853', '2409026818', '2408195893', '2409028778', '2409029600', '2408214539', '2409046980', '2408216337', '2409049050', '2409050134', '2409051104', '2408220977', '2409054690', '2408223659', '2409056658', '2408225565', '2408226307', '2408227277', '2408228187', '2409062032', '2409062886']}

# %%
story_ids = sis.Albums[album_id]['story_ids']
print(story_ids)
story_id = story_ids[1]
sis.show_story(story_id)
print (sis.Stories[story_id]['img_ids'])
print ('-',sis.Stories[story_id])
# Out:
# ['41694', '41691', '41692', '41690', '41693']
# 0: img_id[2409062032], i went to the reptile zoo a few days ago .
# 1: img_id[2408227277], it had a bus that you could sit on to eat .
# 2: img_id[2408223659], we went up to the window to get our food .
# 3: img_id[2408226307], as you can see , it was very good bbq food .
# 4: img_id[2409051104], we had a few drinks and then went home to sleep .
# ['2409062032', '2408227277', '2408223659', '2408226307', '2409051104']
# - {'id': '41691', 'album_id': '72157604508466643', 'sent_ids': ['208455', '208456', '208457', '208458', '208459'], 'img_ids': ['2409062032', '2408227277', '2408223659', '2408226307', '2409051104']}
