# %%
import vist
import matplotlib.pyplot as plt
from datetime import datetime
from pprint import pprint
# %matplotlib inline
plt.rcParams['figure.figsize'] = (10, 10)

# %%
vist_images_dir = 'data/val.images'
vist_annotations_dir = 'data'
sis = vist.Story_in_Sequence(vist_images_dir, vist_annotations_dir, ['val'])
# Out:
# sis's [val] loaded. It took 0.32 seconds.
# Make mapping ...
# Mapping for [Albums][Images][Stories][Sents] done.

# %%
album_id = '117776'
sis.show_album(album_id)
album = sis.Albums[album_id]
print (album)
# Out:
# {'secret': '1ebe589559', 'date_update': '1296684049', 'split': 'val', 'photos': '13', 'description': 'A combination housewarming, grad-school-applications-complete celebration, and going-away party.', 'id': '117776', 'primary': '4681132', 'server': '3', 'date_create': '117776', 'title': 'Cooking Thai', 'farm': '1', 'vist_label': 'cooking_dinner', 'owner': '49503166766@N01', 'story_ids': ['44904', '44902', '44901', '44903', '44900'], 'img_ids': ['4680921', '4681055', '4681101', '4681132', '4681168', '4681214', '4681245', '4681277', '4681310', '4681352', '4681388', '4681425', '4681448']}

# %%
story_ids = sis.Albums[album_id]['story_ids']
story_id = story_ids[0]
sis.show_story(story_id)
print (sis.Stories[story_id]['img_ids'])
print ('-',sis.Stories[story_id])
# Out:
# 0: img_id[4681168], having the family over for dinner tonight ! better get ready .
# 1: img_id[4680921], preparing the meal for the family is a lot of work !
# 2: img_id[4681388], i need to make sure that everything is just right .
# 3: img_id[4681277], putting the finishing touches on the meal . my family should be here soon !
# 4: img_id[4681425], now let 's enjoy the meal with my family . i hope they enjoy it !
# ['4681168', '4680921', '4681388', '4681277', '4681425']
# - {'id': '44904', 'sent_ids': ['224520', '224521', '224522', '224523', '224524'], 'album_id': '117776', 'img_ids': ['4681168', '4680921', '4681388', '4681277', '4681425']}

# %%
print(sis.Sents['224521'])
# Out:
# {'length': 12, 'worker_id': 'KJU1LDR4G7A74GO', 'story_id': '44904', 'original_text': 'Preparing the meal for the family is a lot of work!', 'img_id': '4680921', 'album_id': '117776', 'setting': 'last-3-pick-old-and-tell', 'order': 1, 'id': '224521', 'text': 'preparing the meal for the family is a lot of work !', 'tier': 'story-in-sequence'}
